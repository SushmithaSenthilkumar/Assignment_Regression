# %%
import pickle

# %%
file='insurance_ml_final_model.sav'

# %%
load_model=pickle.load(open('insurance_ml_final_model.sav','rb'))
age=int(input("Enter age:"))
bmi=float(input("enter the BMI:"))
gender=int(input("enter gender{male:0 and female:}:"))
no_of_children=int(input("Enter no of children:"))
smoker=int(input("enter if you smoke:{0:no and 1:yes}"))
result=load_model.predict([[age,bmi,gender,no_of_children,smoker]])
result
# Out:
# Enter age: 29
# enter the BMI: 12
# enter gender{male:0 and female:}: 1
# Enter no of children: 1
# enter if you smoke:{0:no and 1:yes} 0
# array([17690.41901345])
