# %%
#pandas librry to read data set 
import pandas as pd

# %%
#reading client data into dataset variable
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#use get_dummies function of pandas library to create dummy values for one_hot_encoding of categorical nominal data 
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'splitter':['best','random'],
            'max_features':['sqrt', 'log2']}
from sklearn.tree import DecisionTreeRegressor
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_results=grid.cv_results_
table=pd.DataFrame.from_dict(grid_results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009618      0.000299         0.004406        0.000355
# 1        0.007176      0.000731         0.004037        0.000155
# 2        0.008227      0.000767         0.003858        0.000105
# 3        0.006413      0.000299         0.003772        0.000147
# 4        0.007918      0.000843         0.003879        0.000116
# 5        0.007260      0.001134         0.003964        0.000421
# 6        0.008595      0.001279         0.003886        0.000137
# 7        0.006598      0.000895         0.003455        0.000443
# 8        0.034107      0.001833         0.003547        0.000092
# 9        0.029725      0.005717         0.004332        0.000930
# 10       0.036650      0.002767         0.003594        0.000234
# 11       0.028891      0.002845         0.003544        0.000172
# 12       0.008290      0.000681         0.003495        0.000164
# 13       0.006517      0.000760         0.002975        0.000161
# 14       0.008691      0.001116         0.003295        0.000245
# 15       0.005680      0.001032         0.002595        0.000523
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.714791
# 1   {'criterion': 'squared_error', 'max_features':...           0.445272
# 2   {'criterion': 'squared_error', 'max_features':...           0.802112
# 3   {'criterion': 'squared_error', 'max_features':...           0.699503
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.764421
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.647089
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.802886
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.662165
# 8   {'criterion': 'absolute_error', 'max_features'...           0.708459
# 9   {'criterion': 'absolute_error', 'max_features'...           0.674076
# 10  {'criterion': 'absolute_error', 'max_features'...           0.707215
# 11  {'criterion': 'absolute_error', 'max_features'...           0.611083
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.726390
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.675145
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.634816
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.736370
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.567065           0.706959           0.661664
# 1            0.517503           0.655838           0.604443
# 2            0.587318           0.733526           0.721863
# 3            0.593769           0.720475           0.664264
# 4            0.442571           0.650962           0.576381
# 5            0.632603           0.651839           0.563539
# 6            0.591049           0.594786           0.720137
# 7            0.515675           0.676338           0.625165
# 8            0.548919           0.734899           0.527707
# 9            0.641212           0.728221           0.668047
# 10           0.597597           0.705108           0.675297
# 11           0.562674           0.732296           0.697031
# 12           0.610270           0.720639           0.515563
# 13           0.516853           0.665394           0.703273
# 14           0.551213           0.688797           0.694960
# 15           0.665505           0.662017           0.758952
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.682208         0.666537        0.053153                6
# 1            0.615599         0.567731        0.076054               16
# 2            0.711984         0.711361        0.069605                1
# 3            0.631084         0.661819        0.045699                7
# 4            0.731521         0.633171        0.115559               12
# 5            0.615839         0.622182        0.031899               15
# 6            0.746400         0.691052        0.084479                3
# 7            0.653896         0.626648        0.057949               14
# 8            0.687354         0.641468        0.085825               10
# 9            0.690601         0.680431        0.028703                4
# 10           0.704498         0.677943        0.041863                5
# 11           0.630147         0.646646        0.060767                9
# 12           0.574498         0.629472        0.082548               13
# 13           0.629029         0.637939        0.065035               11
# 14           0.672132         0.648384        0.052901                8
# 15           0.711534         0.706876        0.038282                2

# %%
y_predict=grid.predict(independent)

# %%
from sklearn.metrics import r2_score
r2score=r2_score(dependent,y_predict)
r2score
# Out:
# 0.998667156135576

# %%
print(f"best parameter{grid.best_params_} \nr2score value:{r2score}")
# Out:
# best parameter{'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}
# r2score value:0.998667156135576

# %%
age=float(input("Age:"))
bmi=float(input("BMI:"))
children_no=float(input("Children:"))
gender=int(input("Sex Male 0 or 1:"))
smoke_habit=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 20
# BMI: 20
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %% [markdown]
# import matplotlib.pyplot as plt
# from sklearn import tree
# tree.plot_tree(regressor)
# tree

# %%
prediction=grid.predict([[age,bmi,children_no,gender,smoke_habit]])
print(f"Future_Prediction={prediction}")
# Out:
# Future_Prediction=[2803.69785]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
