# %%
#pandas librry to read data set 
import pandas as pd

# %%
#reading client data into dataset variable
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#use get_dummies function of pandas library to create dummy values for one_hot_encoding of categorical nominal data 
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'splitter':['best','random'],
            'max_features':['sqrt', 'log2']}
from sklearn.tree import DecisionTreeRegressor
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_results=grid.cv_results_
table=pd.DataFrame.from_dict(grid_results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012793      0.003164         0.005449        0.001921
# 1        0.009545      0.001777         0.006191        0.000489
# 2        0.011344      0.001335         0.006572        0.000523
# 3        0.011654      0.002072         0.006925        0.000737
# 4        0.010751      0.001940         0.006462        0.000686
# 5        0.008767      0.001369         0.005520        0.000385
# 6        0.009583      0.001039         0.006878        0.002523
# 7        0.008014      0.000804         0.005582        0.000610
# 8        0.031514      0.004761         0.005506        0.000758
# 9        0.032527      0.004636         0.006574        0.001961
# 10       0.048242      0.022695         0.005632        0.000391
# 11       0.026059      0.004969         0.006912        0.003561
# 12       0.027800      0.016171         0.005194        0.000830
# 13       0.011234      0.005657         0.005701        0.000942
# 14       0.008814      0.001981         0.007464        0.005526
# 15       0.007906      0.001567         0.004121        0.000905
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.625754
# 1   {'criterion': 'squared_error', 'max_features':...           0.623780
# 2   {'criterion': 'squared_error', 'max_features':...           0.754914
# 3   {'criterion': 'squared_error', 'max_features':...           0.691724
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.766358
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.664166
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.496392
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.583272
# 8   {'criterion': 'absolute_error', 'max_features'...           0.759848
# 9   {'criterion': 'absolute_error', 'max_features'...           0.697177
# 10  {'criterion': 'absolute_error', 'max_features'...           0.596500
# 11  {'criterion': 'absolute_error', 'max_features'...           0.327935
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.508783
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.662982
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.760263
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.744918
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.512812           0.610871           0.557292
# 1            0.658499           0.452164           0.448715
# 2            0.655564           0.585544           0.693585
# 3            0.549141           0.509880           0.611375
# 4            0.660190           0.584513           0.671522
# 5            0.588024           0.660380           0.466256
# 6            0.595108           0.677644           0.675269
# 7            0.506005           0.642153           0.580382
# 8            0.592358           0.626334           0.672067
# 9            0.419116           0.631977           0.541402
# 10           0.560474           0.667261           0.644124
# 11           0.563585           0.504856           0.576453
# 12           0.439715           0.664226           0.593569
# 13           0.527825           0.624672           0.670803
# 14           0.621743           0.685821           0.626946
# 15           0.584375           0.610914           0.502366
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.672479         0.595842        0.055451                8
# 1            0.568525         0.550337        0.086474               15
# 2            0.584680         0.654858        0.065178                2
# 3            0.489090         0.570242        0.073653               14
# 4            0.484680         0.633453        0.094188                5
# 5            0.534328         0.582631        0.075629               10
# 6            0.595718         0.608026        0.066557                6
# 7            0.542308         0.570824        0.045495               13
# 8            0.670480         0.664217        0.056293                1
# 9            0.567317         0.571398        0.093377               12
# 10           0.724512         0.638574        0.056761                3
# 11           0.631271         0.520820        0.104482               16
# 12           0.650949         0.571448        0.085671               11
# 13           0.502063         0.597669        0.069803                7
# 14           0.490960         0.637147        0.088587                4
# 15           0.481898         0.584894        0.093492                9

# %% [markdown]
# import matplotlib.pyplot as plt
# from sklearn import tree
# tree.plot_tree(regressor)
# tree

# %%
y_predict=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.6397932207646485

# %%
print(f"best parameter{grid.best_params_} \nr2score value:{r2score}")
# Out:
# best parameter{'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}
# r2score value:0.6397932207646485

# %%
age=float(input("Age:"))
bmi=float(input("BMI:"))
children_no=float(input("Children:"))
gender=int(input("Sex Male 0 or 1:"))
smoking_habit=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 20
# BMI: 20
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
prediction=grid.predict([[age,bmi,children_no,gender,smoking_habit]])
print(f"Future_Prediction={prediction}")
# Out:
# Future_Prediction=[18252.85575]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
