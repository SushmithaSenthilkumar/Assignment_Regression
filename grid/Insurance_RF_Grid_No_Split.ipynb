# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_features':['sqrt', 'log2'],
            'n_estimators':[50,100]}
from sklearn.ensemble import RandomForestRegressor
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
grid_results=grid.cv_results_
grid_results
table=pd.DataFrame.from_dict(grid_results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.220219      0.005864         0.011548        0.000471
# 1        0.422981      0.007948         0.019698        0.001539
# 2        0.212180      0.004030         0.011320        0.000455
# 3        0.410792      0.006895         0.018609        0.001046
# 4        0.818074      0.012932         0.010493        0.000346
# 5        1.616719      0.026748         0.018112        0.001055
# 6        0.822833      0.009292         0.010881        0.000584
# 7        1.654649      0.022471         0.018153        0.001131
# 8        0.199768      0.002414         0.010697        0.000380
# 9        0.406020      0.008352         0.018708        0.001003
# 10       0.210664      0.006015         0.011174        0.000669
# 11       0.422054      0.006307         0.019706        0.000813
# 12       0.239237      0.004487         0.011709        0.000362
# 13       0.474906      0.006105         0.019329        0.000638
# 14       0.236036      0.005377         0.010972        0.001514
# 15       0.381004      0.031650         0.013177        0.001915
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  50
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  50
# 3    squared_error               log2                 100
# 4   absolute_error               sqrt                  50
# 5   absolute_error               sqrt                 100
# 6   absolute_error               log2                  50
# 7   absolute_error               log2                 100
# 8     friedman_mse               sqrt                  50
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  50
# 11    friedman_mse               log2                 100
# 12         poisson               sqrt                  50
# 13         poisson               sqrt                 100
# 14         poisson               log2                  50
# 15         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.855435
# 1   {'criterion': 'squared_error', 'max_features':...           0.855768
# 2   {'criterion': 'squared_error', 'max_features':...           0.856956
# 3   {'criterion': 'squared_error', 'max_features':...           0.857906
# 4   {'criterion': 'absolute_error', 'max_features'...           0.852189
# 5   {'criterion': 'absolute_error', 'max_features'...           0.856050
# 6   {'criterion': 'absolute_error', 'max_features'...           0.861188
# 7   {'criterion': 'absolute_error', 'max_features'...           0.855336
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.854177
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.861616
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.859894
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.858133
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859335
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858636
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.855237
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.863949
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.774029           0.856113           0.825944
# 1            0.779658           0.864409           0.832486
# 2            0.776349           0.863090           0.825149
# 3            0.776410           0.859006           0.830146
# 4            0.776192           0.857315           0.819153
# 5            0.786289           0.855557           0.827836
# 6            0.773868           0.854317           0.829394
# 7            0.778801           0.857446           0.827377
# 8            0.773827           0.855478           0.825942
# 9            0.780165           0.861984           0.826897
# 10           0.773994           0.858957           0.822941
# 11           0.776822           0.863731           0.827045
# 12           0.772011           0.857745           0.828808
# 13           0.781769           0.861600           0.831556
# 14           0.776926           0.861292           0.819578
# 15           0.780285           0.855545           0.827984
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.842071         0.830718        0.030401               13
# 1            0.838746         0.834213        0.029584                3
# 2            0.838773         0.832063        0.030916               10
# 3            0.837647         0.832223        0.030086                9
# 4            0.842371         0.829444        0.029675               15
# 5            0.846175         0.834382        0.026126                2
# 6            0.846975         0.833148        0.031476                6
# 7            0.843137         0.832419        0.028868                8
# 8            0.834550         0.828795        0.029729               16
# 9            0.836618         0.833456        0.029999                4
# 10           0.839294         0.831016        0.031622               12
# 11           0.838927         0.832932        0.030992                7
# 12           0.838876         0.831355        0.031825               11
# 13           0.841413         0.834995        0.028819                1
# 14           0.837308         0.830068        0.030315               14
# 15           0.838338         0.833220        0.029320                5

# %%
y_predict=grid.predict(independent)

# %%
from sklearn.metrics import r2_score
r2score=r2_score(dependent,y_predict)
r2score
# Out:
# 0.9767951830143559

# %%
print(f"best parameter{grid.best_params_} \nr2score value:{r2score}")
# Out:
# best parameter{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}
# r2score value:0.9767951830143559

# %%
age=float(input("Age:"))
bmi=float(input("BMI:"))
children_no=float(input("Children:"))
gender=int(input("Sex Male 0 or 1:"))
smoke_habit=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 20
# BMI: 20
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
prediction=grid.predict([[age,bmi,children_no,gender,smoke_habit]])
print(f"Future_Prediction={prediction}")
# Out:
# Future_Prediction=[15997.2346418]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
